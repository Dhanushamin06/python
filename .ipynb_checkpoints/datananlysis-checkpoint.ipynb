# %%
import pandas as pd
df=pd.read_csv("C:/Users/USER/Downloads/cartwheel_data.csv")

# %%
import seaborn as sea

# %%
sea.scatterplot(x="Age", y='Height', hue='Gender', data=df, palette='viridis', sizes=(20, 200))
# Out:
# <Axes: xlabel='Age', ylabel='Height'>
